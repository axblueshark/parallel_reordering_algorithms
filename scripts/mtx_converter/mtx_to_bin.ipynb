# %%
import os, glob
from petsc4py import PETSc
from scipy.io import mmread

# %% [markdown]
# ### Convert matrices from .mtx to .bin

# %%
def mtx_to_bin_mat(input_file: str, output_file: str):
    # load Matrix Market file
    A = mmread(input_file).tocsr()

    # create PETSc matrix (AIJ = compressed sparse row)
    petsc_A = PETSc.Mat().createAIJ(size=A.shape,
                                    csr=(A.indptr, A.indices, A.data))

    # write to PETSc binary format
    viewer = PETSc.Viewer().createBinary(output_file, PETSc.Viewer.Mode.WRITE)
    petsc_A.view(viewer)
    viewer.destroy()

# %%
mat_input_path  = "../../matrices/mtx/"
mat_output_path = "../../matrices/bin/"

os.makedirs(mat_output_path, exist_ok=True)

for f in glob.glob(os.path.join(mat_input_path, "*.mtx")):
    name = os.path.splitext(os.path.basename(f))[0]
    out_file = os.path.join(mat_output_path, name + ".bin")
    print(f"Converting {name}.mtx -> {name}.bin")
    mtx_to_bin_mat(f, out_file)
# Out:
# Converting 04_s_nasa4704.mtx -> 04_s_nasa4704.bin
# Converting 03_s_ex10hs.mtx -> 03_s_ex10hs.bin
# Converting 06_u_bayer03.mtx -> 06_u_bayer03.bin
# Converting 09_u_powersim.mtx -> 09_u_powersim.bin
# Converting 01_s_ex2.mtx -> 01_s_ex2.bin
# Converting 05_u_mhd3200a.mtx -> 05_u_mhd3200a.bin
# Converting 02_u_rbsa480.mtx -> 02_u_rbsa480.bin
# Converting 07_s_bundle1.mtx -> 07_s_bundle1.bin
# Converting 08_s_gyro_k.mtx -> 08_s_gyro_k.bin
# Converting 10_u_airfoil_2d.mtx -> 10_u_airfoil_2d.bin

# %% [markdown]
# ### Convert vectors from .mtx to .bin

# %%
def mtx_to_bin_vec(input_file: str, output_file: str):
    # load Matrix Market file (as dense 2D array)
    v = mmread(input_file)

    # make sure it’s a flat 1D vector
    v = v.reshape(-1)

    # create PETSc vector and set values
    petsc_v = PETSc.Vec().createSeq(len(v))
    petsc_v.setArray(v)

    # write to PETSc binary format
    viewer = PETSc.Viewer().createBinary(output_file, PETSc.Viewer.Mode.WRITE)
    petsc_v.view(viewer)
    viewer.destroy()

# %%
vec_input_path  = "../../matrices/mtx/vec/"
vec_output_path = "../../matrices/bin/vec/"

os.makedirs(vec_output_path, exist_ok=True)

for f in glob.glob(os.path.join(vec_input_path, "*.mtx")):
    name = os.path.splitext(os.path.basename(f))[0]
    out_file = os.path.join(vec_output_path, name + ".bin")
    print(f"Converting {name}.mtx -> {name}.bin")
    mtx_to_bin_vec(f, out_file)
# Out:
# Converting 04_s_nasa4704_b.mtx -> 04_s_nasa4704_b.bin
# Converting 09_u_powersim_b.mtx -> 09_u_powersim_b.bin
# Converting 06_u_bayer03_b.mtx -> 06_u_bayer03_b.bin
# Converting 10_u_airfoil_2d_t.mtx -> 10_u_airfoil_2d_t.bin
